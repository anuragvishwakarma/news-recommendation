# %%
import pandas as pd
import nltk
from sklearn.feature_extraction.text import TfidfVectorizer
nltk.download('punkt')

# %%
# Load News data
news_df = pd.read_table('news.tsv', names=['news_id', 'category', 'subcategory', 'title', 'abstract', 'url', 'title_entities', 'abstract_entities'])

# Load User Click history
behaviors_df = pd.read_table('behaviors.tsv', names=['impression_id', 'user_id', 'time', 'history', 'impressions'])

# %%
# Clean
news_df = news_df.dropna(subset=['title'])
news_df['title_clean'] = news_df['title'].str.lower().str.replace(r'[^a-zA-Z ]', '', regex=True)
